# %% [markdown]
# <a href="https://colab.research.google.com/github/hiten4/Day19PM/blob/main/Day19_PM_Part_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

mean = np.mean(data)
variance = np.var(data)
std_dev = np.std(data)

print(mean, variance, std_dev)

# Histogram
plt.hist(data, bins=30)
plt.title("Normal Distribution")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# 50.193320558223256 95.79049897315173 9.787262077473542

# %% [markdown]
# # 2. PMF (Binomial Distribution)

# %%
def binomial_pmf(n, p):
    k = np.arange(0, n + 1)
    pmf = []

    for i in k:
        prob = math.comb(n, i) * (p ** i) * ((1 - p) ** (n - i))
        pmf.append(prob)

    return k, np.array(pmf)

# %% [markdown]
# # 3. PDF of Normal Distribution (manual)

# %%
def normal_pdf(x, mu, sigma):
    return (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-((x - mu) ** 2) / (2 * sigma ** 2))

x_vals = np.linspace(min(data), max(data), 100)
pdf_vals = normal_pdf(x_vals, mean, std_dev)

# %% [markdown]
# # 4. Statistics + skewness

# %%
median = np.median(data)

counts = Counter(data.round())
mode = counts.most_common(1)[0][0]

skewness = (mean - median) / std_dev

print(mean, median, mode, skewness)

if skewness > 0:
    print("Right skewed")
elif skewness < 0:
    print("Left skewed")
else:
    print("Symmetric")
# Out:
# 50.193320558223256 50.25300612234888 52.0 -0.006098290170751177
# Left skewed

# %% [markdown]
# # 5. Coin toss simulation

# %%
np.random.seed(0)
tosses = np.random.choice([0, 1], size=1000)

prob_heads = tosses.mean()

print("Estimated probability of heads:", prob_heads)
print("Theoretical probability:", 0.5)
# Out:
# Estimated probability of heads: 0.504
# Theoretical probability: 0.5
